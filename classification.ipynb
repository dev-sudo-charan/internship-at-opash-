# %%
# !pip install --upgrade ultralytics

# %%
# !unzip /content/ChildAdultClassifier.v2i.folder.zip
# Out:
# Archive:  /content/ChildAdultClassifier.v2i.folder.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#    creating: test/
#    creating: test/adults/
#  extracting: test/adults/102_jpg.rf.8a180f9c8257f9b8b821f58a96206096.jpg
#  extracting: test/adults/104_jpg.rf.e8b9efef34dd87ccc076bfc1e0040394.jpg
#  extracting: test/adults/105_jpg.rf.c2b6c09c1f218fbb04503b992516e423.jpg
#  extracting: test/adults/110_jpg.rf.b96145d13ce159dc5b6ad4178e4527ce.jpg
#  extracting: test/adults/115_jpg.rf.761c5ab8b314c7db68c23e44ddfe6bf4.jpg
#  extracting: test/adults/120_jpg.rf.370d02d0c85f16fdbaefb4f82b72edf9.jpg
#  extracting: test/adults/121_jpg.rf.870d51ec1ef21927112a136df102099c.jpg
#  extracting: test/adults/126_jpg.rf.361c508585ea35a77aa17afc6b8fa02c.jpg
#  extracting: test/adults/12_jpg.rf.a8977c6a9af1dbfd596d1dd0c8cb30b5.jpg
#  extracting: test/adults/131_jpg.rf.888531a8cee7cefea7fe340f93737f53.jpg
#  extracting: test/adults/139_jpg.rf.c081d0980a9bfa49018f1475137f4dc7.jpg
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolo11n-cls.pt')

results = model.train(data='/content', epochs=1, imgsz=640)
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
results = model("/content/adult.jpg", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/adult.jpg: 640x640 adults 1.00, children 0.00, 5.1ms
# Speed: 28.6ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/classify/predict
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
results = model("/content/teen.jpg", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/teen.jpg: 640x640 children 0.59, adults 0.41, 4.8ms
# Speed: 16.0ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/classify/predict
# <PIL.Image.Image image mode=RGB size=264x191>

# %%
results = model("/content/20s person.jpg", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/20s person.jpg: 640x640 adults 0.99, children 0.01, 4.5ms
# Speed: 13.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/classify/predict
# <PIL.Image.Image image mode=RGB size=276x183>

# %%
results = model("/content/dwarf.jpg", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/dwarf.jpg: 640x640 adults 0.87, children 0.13, 8.8ms
# Speed: 24.8ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/classify/predict
# <PIL.Image.Image image mode=RGB size=194x259>

# %%
results = model("/content/dwarf2.jpg", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/dwarf2.jpg: 640x640 adults 0.84, children 0.16, 4.9ms
# Speed: 15.3ms preprocess, 4.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/classify/predict
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
results = model("/content/test.jpg", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/test.jpg: 640x640 adults 0.83, children 0.17, 6.3ms
# Speed: 15.7ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/classify/predict
# <PIL.Image.Image image mode=RGB size=210x240>

# %%
results = model("/content/test2.jpg", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/test2.jpg: 640x640 children 0.93, adults 0.07, 4.9ms
# Speed: 16.6ms preprocess, 4.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/classify/predict
# <PIL.Image.Image image mode=RGB size=194x259>

# %%
results = model("/content/test3.jpg", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/test3.jpg: 640x640 adults 0.99, children 0.01, 6.2ms
# Speed: 24.3ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/classify/predict
# <PIL.Image.Image image mode=RGB size=194x259>

# %%
results = model("/content/test4.jpg", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/test4.jpg: 640x640 children 0.97, adults 0.03, 6.0ms
# Speed: 26.6ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/classify/predict
# <PIL.Image.Image image mode=RGB size=172x293>

# %%
results = model("/content/test5.jpg", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/test5.jpg: 640x640 children 1.00, adults 0.00, 4.9ms
# Speed: 16.5ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/classify/predict
# <PIL.Image.Image image mode=RGB size=265x190>
