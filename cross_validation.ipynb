# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
iris = load_iris()

# %%
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# %%
'''

HERE I AM COMPARING DIFFERENT MODELS USING CROSS VALIDATION

'''

# %%
logreg_scores = cross_val_score(LogisticRegression(max_iter=150), iris.data, iris.target, cv=skf)
logreg_scores
# Out:
# array([1.  , 0.94, 0.96])

# %%
np.average(logreg_scores)
# Out:
# np.float64(0.9666666666666667)

# %%
svm_scores = cross_val_score(SVC(), iris.data, iris.target,cv=skf)
svm_scores
# Out:
# array([1.  , 0.94, 0.96])

# %%
np.average(svm_scores)
# Out:
# np.float64(0.9666666666666667)

# %%
tree_scores = cross_val_score(DecisionTreeClassifier(), iris.data, iris.target,cv=skf)
tree_scores
# Out:
# array([1.  , 0.92, 0.94])

# %%
np.average(tree_scores)
# Out:
# np.float64(0.9533333333333333)

# %%
forest_scores = cross_val_score(RandomForestClassifier(), iris.data, iris.target,cv=skf)
forest_scores
# Out:
# array([1.  , 0.94, 0.92])

# %%
np.average(forest_scores)
# Out:
# np.float64(0.9533333333333333)

# %%
'''

USING CROSS VALIDATION FOR HYPERPARAMETER TUNING

'''
# Out:
# '\n\nUSING CROSS VALIDATION FOR HYPERPARAMETER TUNING\n\n'

# %%
'''
1. SVM
'''
# Out:
# '\n1. SVM\n'

# %%
svm_scores = cross_val_score(SVC(C=1.0), iris.data, iris.target)
svm_scores
# Out:
# array([0.96666667, 0.96666667, 0.96666667, 0.93333333, 1.        ])

# %%
svm_scores = cross_val_score(SVC(C=0.1), iris.data, iris.target)
svm_scores
# Out:
# array([0.9       , 0.93333333, 0.9       , 0.96666667, 0.9       ])

# %%
svm_scores = cross_val_score(SVC(C=0.01), iris.data, iris.target)
svm_scores
# Out:
# array([0.9       , 0.93333333, 0.9       , 0.96666667, 0.93333333])

# %%
'''
2. LOGISTIC REGRESSION
'''
# Out:
# '\n2. LOGISTIC REGRESSION\n'

# %%
logreg_scores = cross_val_score(LogisticRegression(C=1.0, max_iter=150), iris.data, iris.target)
logreg_scores
# Out:
# array([0.96666667, 1.        , 0.93333333, 0.96666667, 1.        ])

# %%
logreg_scores = cross_val_score(LogisticRegression(C=10.0, max_iter=150), iris.data, iris.target)
logreg_scores
# Out:
# array([0.96666667, 1.        , 0.96666667, 0.93333333, 1.        ])

# %%
logreg_scores = cross_val_score(LogisticRegression(C=0.01, max_iter=150), iris.data, iris.target)
logreg_scores
# Out:
# array([0.76666667, 0.93333333, 0.76666667, 0.9       , 0.93333333])

# %%
'''
3. DECISION TREE
'''
# Out:
# '\n3. DECISION TREE\n'

# %%
tree_scores = cross_val_score(DecisionTreeClassifier(max_depth=10), iris.data, iris.target)
tree_scores
# Out:
# array([0.96666667, 0.96666667, 0.9       , 0.93333333, 1.        ])

# %%
tree_scores = cross_val_score(DecisionTreeClassifier(max_depth=1), iris.data, iris.target)
tree_scores
# Out:
# array([0.66666667, 0.66666667, 0.66666667, 0.66666667, 0.66666667])

# %%
tree_scores = cross_val_score(DecisionTreeClassifier(max_depth=5), iris.data, iris.target)
tree_scores
# Out:
# array([0.96666667, 0.96666667, 0.9       , 0.93333333, 1.        ])

# %%
'''
4. RANDOM FOREST
'''
# Out:
# '\n4. RANDOM FOREST\n'

# %%
forest_scores = cross_val_score(RandomForestClassifier(n_estimators=100), iris.data, iris.target)
forest_scores
# Out:
# array([0.96666667, 0.96666667, 0.93333333, 0.96666667, 1.        ])

# %%
forest_scores = cross_val_score(RandomForestClassifier(n_estimators=20), iris.data, iris.target)
forest_scores
# Out:
# array([0.96666667, 0.96666667, 0.9       , 0.9       , 1.        ])

# %%
forest_scores = cross_val_score(RandomForestClassifier(n_estimators=3), iris.data, iris.target)
forest_scores
# Out:
# array([1.        , 0.96666667, 0.93333333, 0.9       , 1.        ])
